# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# annotated-types           0.7.0
# anyio                     4.4.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.15.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# certifi                   2024.2.2
# cffi                      1.16.0
# charset-normalizer        3.3.2
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.2.1
# cycler                    0.12.1
# debugpy                   1.8.1
# decorator                 5.1.1
# defusedxml                0.7.1
# distro                    1.9.0
# elastic-transport         8.13.1
# elasticsearch             8.14.0
# exceptiongroup            1.2.1
# executing                 2.0.1
# ...

# %%
# !pip freeze | grep -E "^(tqdm|pandas|elasticsearch|notebook|ipywidgets|scikit-learn|python-docx)"
# Out:
# elasticsearch==8.14.0
# ipywidgets==8.1.3
# notebook==7.1.2
# notebook_shim==0.2.4
# pandas==2.2.2
# python-docx==1.1.2
# scikit-learn==1.5.0
# tqdm==4.66.4

# %%
import requests
import io
import docx

# %%
field_id = "19bnYs80DwuUimHM65UV3sylsCn2j1vziPOwzBwQrebw"
url = f"https://docs.google.com/document/d/{field_id}/export?format=docx"

# %%
response = requests.get(url)

# %%
response.raise_for_status()

# %%
response
# Out:
# <Response [200]>

# %%
with io.BytesIO(response.content) as f_in:
    doc = docx.Document(f_in)

# %%
doc.paragraphs
# Out:
# ...
#  ...]

# %%
p = doc.paragraphs[1]
p.text, p.style
# Out:
# ('General course-related questions',
#  _ParagraphStyle('Heading 1') id: 124131344652064)

# %%
p = doc.paragraphs[2]
p.text, p.style
# Out:
# ('Course - When will the course start? ',
#  _ParagraphStyle('Heading 2') id: 125771509529328)

# %%
p = doc.paragraphs[3]
p.text, p.style
# Out:
# ("The exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.",
#  _ParagraphStyle('normal') id: 125771522771600)

# %%
p = doc.paragraphs[1]
p.text, p.style.name.lower()
# Out:
# ('General course-related questions', 'heading 1')

# %%
for p in doc.paragraphs:
    print(p.text)
# Out:
# rThe purpose of this document is to capture frequently asked technical questions
# General course-related questions
# Course - When will the course start?
# The exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.
# Subscribe to course public Google Calendar (it works from Desktop only).
# Register before the course starts using this link.
# Join the course Telegram channel with announcements.
# Don’t forget to register in DataTalks.Club's Slack and join the channel.
#
# Course - What are the prerequisites for this course?
# GitHub - DataTalksClub/data-engineering-zoomcamp#prerequisites
# Course - Can I still join the course after the start date?
# Yes, even if you don't register, you're still eligible to submit the homeworks.
# Be aware, however, that there will be deadlines for turning in the final projects. So don't leave everything for the last minute.
# ...

# %%
question_heading_style = "heading 2"
section_heading_style = "heading 1"

# %%
documents = []
current_answer = []
current_section = ''
current_question = ''

for p in doc.paragraphs:
    p_text = p.text.strip()
    p_style = p.style.name.lower()

    if p_text == '' :
        continue

    if p_style == section_heading_style:
        current_section = p_text
        current_answer = []
        continue
    
     
    if p_style == question_heading_style:
        if current_section and current_question and current_answer:
            answer = "\n".join(current_answer)
            documents.append({
                "section": current_section,
                "question": current_question,
                "text": answer
            })
        current_question = p_text
        current_answer = []
        continue
        
    current_answer.append(p_text)
if current_answer:
    answer = "\n".join(current_answer)
    documents.append({
        "section": current_section,
        "question": current_question,
        "text": answer
    })

# %%
documents[0]
# Out:
# {'section': 'General course-related questions',
#  'question': 'Course - When will the course start?',
#  'text': "The exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel."}

# %%
documents[5]
# Out:
# {'section': 'General course-related questions',
#  'question': 'Course - When will the course start?',
#  'text': ''}

# %%
documents[2]
# Out:
# {'section': 'General course-related questions',
#  'question': 'Course - What are the prerequisites for this course?',
#  'text': "The exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.\nGitHub - DataTalksClub/data-engineering-zoomcamp#prerequisites"}

# %%
len(documents)
# Out:
# 455

# %%
documents[454]
# Out:
# {'section': 'Triggers in Mage via CLI',
#  'question': 'Basic Commands',
# ...
