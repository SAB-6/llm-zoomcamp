# %%
import json

with open('documents-with-ids.json', 'rt') as f_in:
    documents = json.load(f_in)

# %%
from elasticsearch import Elasticsearch

es_client = Elasticsearch('http://localhost:9200') 

index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "text": {"type": "text"},
            "section": {"type": "text"},
            "question": {"type": "text"},
            "course": {"type": "keyword"},
            "id": {"type": "keyword"},
        }
    }
}

index_name = "course-questions"

es_client.indices.delete(index=index_name, ignore_unavailable=True)
es_client.indices.create(index=index_name, body=index_settings)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'course-questions'})

# %%
from tqdm.auto import tqdm

for doc in tqdm(documents):
    es_client.index(index=index_name, document=doc)
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]

# %%
def elastic_search(query, course):
    search_query = {
        "size": 5,
        "query": {
            "bool": {
                "must": {
                    "multi_match": {
                        "query": query,
                        "fields": ["question^3", "text", "section"],
                        "type": "best_fields"
                    }
                },
                "filter": {
                    "term": {
                        "course": course
                    }
                }
            }
        }
    }

    response = es_client.search(index=index_name, body=search_query)
    
    result_docs = []
    
    for hit in response['hits']['hits']:
        result_docs.append(hit['_source'])
    
    return result_docs

# %%
elastic_search(
    query="I just discovered the course. Can I still join?",
    course="data-engineering-zoomcamp"
)
# Out:
# [{'text': "Yes, even if you don't register, you're still eligible to submit the homeworks.\nBe aware, however, that there will be deadlines for turning in the final projects. So don't leave everything for the last minute.",
#   'section': 'General course-related questions',
#   'question': 'Course - Can I still join the course after the start date?',
#   'course': 'data-engineering-zoomcamp',
#   'id': '7842b56a'},
#  {'text': 'You can start by installing and setting up all the dependencies and requirements:\nGoogle cloud account\nGoogle Cloud SDK\nPython 3 (installed with Anaconda)\nTerraform\nGit\nLook over the prerequisites and syllabus to see if you are comfortable with these subjects.',
#   'section': 'General course-related questions',
#   'question': 'Course - What can I do before the course starts?',
#   'course': 'data-engineering-zoomcamp',
#   'id': '63394d91'},
#  {'text': 'Yes, we will keep all the materials after the course finishes, so you can follow the course at your own pace after it finishes.\nYou can also continue looking at the homeworks and continue preparing for the next cohort. I guess you can also start working on your final capstone project.',
#   'section': 'General course-related questions',
#   'question': 'Course - Can I follow the course after it finishes?',
#   'course': 'data-engineering-zoomcamp',
#   'id': 'a482086d'},
#  {'text': 'Yes, the slack channel remains open and you can ask questions there. But always sDocker containers exit code w search the channel first and second, check the FAQ (this document), most likely all your questions are already answered here.\nYou can also tag the bot @ZoomcampQABot to help you conduct the search, but don’t rely on its answers 100%, it is pretty good though.',
#   'section': 'General course-related questions',
#   'question': 'Course - Can I get support if I take the course in the self-paced mode?',
#   'course': 'data-engineering-zoomcamp',
#   'id': 'eb56ae98'},
#  {'text': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'section': 'General course-related questions',
#   'question': 'Course - I have registered for the Data Engineering Bootcamp. When can I expect to receive the confirmation email?',
#   'course': 'data-engineering-zoomcamp',
#   'id': '0bbf41ec'}]

# %%
import pandas as pd

# %%
df_ground_truth = pd.read_csv('ground-truth-data.csv')

# %%
ground_truth = df_ground_truth.to_dict(orient='records')

# %%
ground_truth
# Out:
# [{'question': 'What is the start date and time for the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c02e79ef'},
#  {'question': 'How can I keep track of the course schedule?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c02e79ef'},
#  {'question': "When is the first 'Office Hours' session for the course?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c02e79ef'},
#  {'question': 'Is there a specific form to register before the course starts?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c02e79ef'},
#  {'question': "Where can I join the course's Telegram channel for announcements?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c02e79ef'},
#  {'question': 'Where can I find the prerequisites for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1f6520ca'},
#  {'question': 'What should I check before enrolling in the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1f6520ca'},
#  {'question': 'Is there a way to know the required background for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1f6520ca'},
#  {'question': 'How do I access the list of prerequisites for the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1f6520ca'},
#  {'question': 'Where is the information about the course prerequisites located?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1f6520ca'},
#  {'question': 'Can I join the course after it starts?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7842b56a'},
#  {'question': "Am I eligible to submit homework if I don't register?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '7842b56a'},
#  {'question': 'Are there deadlines for final projects?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7842b56a'},
#  {'question': 'What happens if I leave everything for the last minute?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7842b56a'},
#  {'question': 'Can I participate in the course without registering?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7842b56a'},
#  {'question': "Have I been accepted into the Data Engineering Bootcamp if I don't receive a confirmation email?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '0bbf41ec'},
#  {'question': 'Is it mandatory to register for the Data Engineering Bootcamp in order to start learning?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0bbf41ec'},
#  {'question': 'Do I need to wait for a confirmation email before beginning the Data Engineering Bootcamp?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0bbf41ec'},
#  {'question': "What is the purpose of registration for the Data Engineering Bootcamp if acceptance doesn't require it?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '0bbf41ec'},
#  {'question': 'Can I begin submitting homework for the Data Engineering Bootcamp without being on a registered list?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0bbf41ec'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': '63394d91'},
#  {'question': 'How many Zoom Camps are held in a year?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2ed9b986'},
#  {'question': 'What are the specific months for the Data-Engineering Zoomcamp?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2ed9b986'},
#  {'question': 'Is there more than one live cohort for Data-Engineering in a year?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2ed9b986'},
#  {'question': 'Can I take the Zoomcamps at my own pace without joining a live cohort?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2ed9b986'},
#  {'question': 'Are the schedules for the Zoomcamp cohorts pretty much the same each year?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2ed9b986'},
#  {'question': 'Is the cohort for 2024 using Mage AI rather than Prefect?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '93e2c8ed'},
#  {'question': 'Are the terraform videos different in the 2024 cohort?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '93e2c8ed'},
#  {'question': 'Was Prefect used in the 2023 cohort instead of Airflow?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '93e2c8ed'},
#  {'question': 'Will the 2024 edition have re-recorded terraform content?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '93e2c8ed'},
#  {'question': 'Are there significant changes between the 2023 and 2024 cohorts?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '93e2c8ed'},
#  {'question': 'Can I access the course materials after it ends?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a482086d'},
#  {'question': 'Will I be able to view homework assignments after the course concludes?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a482086d'},
#  {'question': 'Is it possible to prepare for the next cohort after finishing the current course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a482086d'},
#  {'question': 'Can I start my final capstone project after the course finishes?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a482086d'},
#  {'question': 'Do I need to complete all the coursework before the course officially ends?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a482086d'},
#  {'question': 'Can I receive help if I take the course at my own pace?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb56ae98'},
#  {'question': 'Is there a channel where I can ask questions during the self-paced course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb56ae98'},
#  {'question': 'What should I do first before asking a question in the slack channel?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb56ae98'},
#  {'question': 'Can I use a bot to help find answers in the FAQ?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb56ae98'},
#  {'question': 'How reliable is the bot for answering questions in the slack channel?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb56ae98'},
#  {'question': 'Which YouTube playlist contains all the main videos for the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '4292531b'},
#  {'question': 'Where can I find the updated video links with thumbnails?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '4292531b'},
#  {'question': 'Are there additional year-specific playlists available?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '4292531b'},
#  {'question': 'Where is the MAIN PLAYLIST link?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '4292531b'},
#  {'question': 'Where can I find the course playlist pinned for quick access?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '4292531b'},
#  {'question': 'What is the expected weekly time commitment for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ea739c65'},
#  {'question': 'How many hours per week should I dedicate to this course based on my experience?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ea739c65'},
#  {'question': 'How do I calculate the weekly hours needed for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ea739c65'},
#  {'question': 'What is the range of hours per week recommended for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ea739c65'},
#  {'question': 'How can I adjust my weekly study hours for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ea739c65'},
#  {'question': 'Can I receive a certificate by completing the course at my own pace?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cb257ee5'},
#  {'question': 'Is it possible to obtain certification if I go through the course without joining a live cohort?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cb257ee5'},
#  {'question': 'Will I get a certificate if I finish the course in self-paced mode?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cb257ee5'},
#  {'question': "Can I earn a certificate if I don't join the live sessions of the course?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cb257ee5'},
#  {'question': 'Do I need to be part of a live cohort to be awarded a certificate at the end of the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cb257ee5'},
#  {'question': 'Where can I find the video link for the Office Hour sessions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04aa4897'},
#  {'question': 'How can students participate during the workshop sessions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04aa4897'},
#  {'question': 'Where should we submit our questions for Office Hour sessions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04aa4897'},
#  {'question': 'How will I know when the Office Hour sessions begin?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04aa4897'},
#  {'question': "Why shouldn't I post my questions directly in the YouTube chat?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '04aa4897'},
#  {'question': "Will the 'Office Hours' be recorded if I can't attend?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '9681be3b'},
#  {'question': "Are the 'Office Hours' sessions available after the live session?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '9681be3b'},
#  {'question': "Can I watch 'Office Hours' at any time if I miss it?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '9681be3b'},
#  {'question': 'Is there a way to rewatch the workshop sessions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9681be3b'},
#  {'question': "How soon are 'Office Hours' recordings made available?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '9681be3b'},
#  {'question': 'Where can I find the deadlines for homework and projects?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1daf537'},
#  {'question': 'How can I get updates about homework extensions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1daf537'},
#  {'question': 'Where are the latest homework deadlines posted?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1daf537'},
#  {'question': 'Who announces news about homework deadline extensions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1daf537'},
#  {'question': 'Where should I check if the homework deadlines have been updated?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1daf537'},
#  {'question': 'Are late homework submissions accepted?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'be5bfee4'},
#  {'question': 'What happens if I submit homework after the due date?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'be5bfee4'},
#  {'question': 'Can I confirm my homework submission after the due date?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'be5bfee4'},
#  {'question': 'Is there any way to submit homework after the deadline?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'be5bfee4'},
#  {'question': 'Where can I find the date-timestamp for my homework submission?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'be5bfee4'},
#  {'question': 'What is the homework URL?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0e424a44'},
#  {'question': 'Can GitLab or Bitbucket be used for homework?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0e424a44'},
#  {'question': 'Which location should contain my homework code?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0e424a44'},
#  {'question': 'Is GitHub mandatory for submitting homework?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0e424a44'},
#  {'question': 'Where should a reasonable person find my weekly exercises?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0e424a44'},
#  {'question': 'How are homework assignments graded in the course management platform?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '29865466'},
#  {'question': 'Where can I see the total number of points I have earned for a homework assignment?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '29865466'},
#  {'question': 'What contributes to the total points listed on the leaderboard?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '29865466'},
#  {'question': 'How many points do you get for submitting an FAQ?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '29865466'},
#  {'question': "How many points do you receive for each 'learning in public' link?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '29865466'},
#  {'question': 'How do I find my name on the leaderboard?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '016d46a1'},
#  {'question': 'What is my display name on the homework submissions leaderboard?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '016d46a1'},
#  {'question': 'How can I check which name I am listed under on the leaderboard?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '016d46a1'},
#  {'question': 'Where can I see my Display name for assignments?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '016d46a1'},
#  {'question': 'How do I change the random name assigned to me on the homework leaderboard?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '016d46a1'},
#  {'question': 'Is Python 3.9 still recommended to use in 2024?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '47972cb1'},
#  {'question': 'Why is Python 3.9 recommended for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '47972cb1'},
#  {'question': 'Are Python 3.10 and 3.11 compatible with this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '47972cb1'},
#  {'question': 'Is it simpler to troubleshoot with Python 3.9?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '47972cb1'},
#  {'question': 'Is there any issue with using Python 3.10 or 3.11 in the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '47972cb1'},
#  {'question': 'Is it better to use my local machine or a virtual machine for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ddf6c1b3'},
#  {'question': 'What should Windows users be aware of when setting up their environment?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ddf6c1b3'},
#  {'question': 'How do I start if I want to work locally on my laptop?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ddf6c1b3'},
#  {'question': 'Can I use GitHub Codespaces for my environment setup?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ddf6c1b3'},
#  {'question': 'What are the benefits of using a virtual machine for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ddf6c1b3'},
#  {'question': 'Can I use GitHub Codespaces instead of CLI or Git Bash for data ingestion?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ac25d3af'},
#  {'question': 'Does GitHub Codespaces provide pre-installed tools like Docker and Python?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ac25d3af'},
#  {'question': 'Is GitHub Codespaces a good alternative to creating a Docker file manually?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ac25d3af'},
#  {'question': 'Are computing Linux resources available in GitHub Codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ac25d3af'},
#  {'question': 'Can I open any GitHub repository directly in a GitHub Codespace?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ac25d3af'},
#  {'question': 'Do I have to use GitHub codespaces if I have PostgreSQL and Docker installed?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '251218fc'},
#  {'question': 'Can I complete the course using my laptop instead of Github codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '251218fc'},
#  {'question': 'Is it mandatory to use GCP VM for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '251218fc'},
#  {'question': 'Are there any specific requirements for the environment in this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '251218fc'},
#  {'question': 'Can I choose my preferred platform for completing the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '251218fc'},
#  {'question': 'Do I need both GitHub Codespaces and GCP for the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3c0114ce'},
#  {'question': 'Is using BigQuery part of the course necessary?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3c0114ce'},
#  {'question': 'Can I set up a local environment instead of using GitHub Codespaces or GCP?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3c0114ce'},
#  {'question': 'Which environment is recommended for the end project, GitHub Codespaces or GCP?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3c0114ce'},
#  {'question': 'Will both GitHub Codespaces and GCP be required throughout the entire course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3c0114ce'},
#  {'question': 'What steps should I follow to open the Run command window on my Windows machine?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f43f5fe7'},
#  {'question': 'How can I open the Registry Editor on a Windows machine?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f43f5fe7'},
#  {'question': 'Which registry value should be changed when connecting to a GCP VM using VSCode on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f43f5fe7'},
#  {'question': "Where is the 'known_hosts' file located in Windows for deleting the fingerprint?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f43f5fe7'},
#  {'question': "What specific value should the 'Autorun' entry be changed to in the Registry Editor for troubleshooting?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f43f5fe7'},
#  {'question': 'Why are we using GCP for the environment setup instead of other cloud providers?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd061525d'},
#  {'question': 'Am I restricted to using only GCP for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd061525d'},
#  {'question': 'Do I need a credit card to sign up for a free GCP account?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd061525d'},
#  {'question': 'What are some benefits of using GCP for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd061525d'},
#  {'question': 'Can I use AWS or Azure instead of GCP if I am more comfortable with those platforms?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd061525d'},
#  {'question': 'Do I need to pay for cloud services during the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1cd01b2c'},
#  {'question': 'Is a payment required for using GCP?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1cd01b2c'},
#  {'question': 'Are there any free trial options for cloud services?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1cd01b2c'},
#  {'question': 'Will GCP offer a free trial for our course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1cd01b2c'},
#  {'question': 'Should I expect any cloud service charges if I use GCP?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1cd01b2c'},
#  {'question': 'Is it possible to take this course without using any cloud providers?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e4a7c3b0'},
#  {'question': 'Can I run almost everything from this course locally?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e4a7c3b0'},
#  {'question': 'Are there any course materials that require the use of GCP?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e4a7c3b0'},
#  {'question': 'Can you provide a guide for setting up a home lab for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e4a7c3b0'},
#  {'question': 'Is BigQuery the only tool in the course that cannot be run locally?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e4a7c3b0'},
#  {'question': 'Can I use AWS for the course, and if so, how should I adapt the information on the videos?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7cd1912e'},
#  {'question': 'What is the final capstone project requirement if I use AWS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7cd1912e'},
#  {'question': 'Will I face difficulties with receiving help if I use AWS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7cd1912e'},
#  {'question': 'Are there many coursemates with AWS experience who can assist me?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7cd1912e'},
#  {'question': 'Where can I find information about using a different tool instead of the one used in the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7cd1912e'},
#  {'question': 'Will there be any live zoom calls besides the Office Hour?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '52393fb3'},
#  {'question': 'Are live calls planned during the Capstone period?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '52393fb3'},
#  {'question': 'How will we be informed about additional calls?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '52393fb3'},
#  {'question': 'What is the purpose of the calls during the Capstone?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '52393fb3'},
#  {'question': 'When should we expect announcements for extra zoom calls?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '52393fb3'},
#  {'question': 'Are we using the NYC Trip data for January 2021?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '10515af5'},
#  {'question': 'Will the project remain the same as last year’s?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '10515af5'},
#  {'question': 'Is the data for the project available?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '10515af5'},
#  {'question': 'Are we using the 2022 data for the project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '10515af5'},
#  {'question': 'Where can I find the data for the project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '10515af5'},
#  {'question': 'Was the 2022 repo removed?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cdb86a97'},
#  {'question': 'Can I still access 2022 materials?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cdb86a97'},
#  {'question': 'Have the 2022 resources been relocated?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cdb86a97'},
#  {'question': 'Is the 2022 repository still available?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cdb86a97'},
#  {'question': 'Where did the 2022 content go?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cdb86a97'},
#  {'question': 'Can I use Airflow for my final project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3e0114ad'},
#  {'question': 'Is it allowed to use any tool for the final project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3e0114ad'},
#  {'question': 'Are we restricted to specific tools for our project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3e0114ad'},
#  {'question': 'Can other tools besides Airflow be used for the project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3e0114ad'},
#  {'question': 'Is there flexibility in tool choice for project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3e0114ad'},
#  {'question': 'Is it allowed to substitute Airflow for the tool used in the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b2799574'},
#  {'question': 'Can AWS be used instead of GCP products in this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b2799574'},
#  {'question': 'May I choose Prefect over Mage for the tasks in the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b2799574'},
#  {'question': 'Is using Tableau in place of Metabase permissible in this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b2799574'},
#  {'question': 'What are the implications if I choose to use a different data stack for the capstone project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b2799574'},
#  {'question': 'How can I help improve the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f19301f'},
#  {'question': 'What should I do if I find the repository useful?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f19301f'},
#  {'question': 'Where should I contribute if I spot an error in the text?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f19301f'},
#  {'question': 'What actions can I take to support the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f19301f'},
#  {'question': 'How can I share this course with others?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f19301f'},
#  {'question': 'Is Linux the best OS for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c700adb'},
#  {'question': 'Will the course work on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c700adb'},
#  {'question': 'Does this course support macOS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c700adb'},
#  {'question': 'What OS did students use last year?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c700adb'},
#  {'question': 'Can I use any OS for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c700adb'},
#  {'question': 'What should Windows users do when they encounter *.sh shell scripts in later modules?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '44b14808'},
#  {'question': 'Is using git bash or MINGW64 sufficient for running *.sh files on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '44b14808'},
#  {'question': 'Why is the WSL environment setup recommended for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '44b14808'},
#  {'question': 'Which later modules require the use of *.sh shell scripts?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '44b14808'},
#  {'question': 'How have past cohorts dealt with the issue of running shell scripts on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '44b14808'},
#  {'question': 'Can you recommend any books or additional resources for the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '76e4baf6'},
#  {'question': 'Where can I find recommended books and resources?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '76e4baf6'},
#  {'question': 'Is there a list of extra learning materials available?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '76e4baf6'},
#  {'question': 'Are there any additional documents you recommend?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '76e4baf6'},
#  {'question': 'Can you point me to any supplementary readings?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '76e4baf6'},
#  {'question': 'What are Project Attempt #1 and Project Attempt #2?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '48b533a8'},
#  {'question': 'What happens if I miss the first project deadline?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '48b533a8'},
#  {'question': 'Can I submit a project after failing the first attempt?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '48b533a8'},
#  {'question': 'Is there an opportunity for a second project submission?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '48b533a8'},
#  {'question': 'How many chances do I get for the project submission?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '48b533a8'},
#  {'question': 'What is the first step to troubleshoot an issue on my own?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '954044d1'},
#  {'question': 'How can I find out what the error means?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '954044d1'},
#  {'question': 'What should I do if reinstalling an application fails to solve the issue?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '954044d1'},
#  {'question': "Where can I ask for help if I can't solve a problem using the FAQ?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '954044d1'},
#  {'question': 'What information should I include when asking a question in Slack?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '954044d1'},
#  {'question': "When should I ask a question if the troubleshooting guide doesn't help?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a820b9b3'},
#  {'question': 'What details should I provide about my operating system when asking a question?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a820b9b3'},
#  {'question': 'Should I include the specific command I ran when asking a question?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a820b9b3'},
#  {'question': 'How important is it to mention the error line number and check for typos?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a820b9b3'},
#  {'question': 'Why is it essential to state what I have tried that did not work?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a820b9b3'},
#  {'question': 'How do I use GitHub for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f2945cd2'},
#  {'question': 'What should I do after creating a GitHub account?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f2945cd2'},
#  {'question': 'How can I access the instructors’ code?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f2945cd2'},
#  {'question': 'Where can I find a tutorial for creating my own repositories?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f2945cd2'},
#  {'question': 'What files should I avoid storing in a Git repository?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f2945cd2'},
#  {'question': "What should be done if I get the 'missing separator' error in a Makefile?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb9d376f'},
#  {'question': "How do I fix the 'Error: Makefile:2: *** missing separator. Stop.'?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb9d376f'},
#  {'question': 'What is the solution for spaces used as tabs in Makefile?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb9d376f'},
#  {'question': 'Why do I get an error in Makefile when using spaces instead of tabs?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb9d376f'},
#  {'question': 'What steps should I follow to convert spaces to tabs in VS Code?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb9d376f'},
#  {'question': 'How can I open an HTML file with a Windows browser from Linux running on WSL?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72f25f6d'},
#  {'question': 'What tool do I need to install to open HTML files from Linux on WSL in a Windows browser?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72f25f6d'},
#  {'question': 'What command should I use to open an HTML file in a Windows browser from Linux on WSL?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72f25f6d'},
#  {'question': 'How can I specify a particular browser to open HTML files from WSL?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72f25f6d'},
#  {'question': 'What is the format to set a custom browser for wslview in Linux on WSL?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72f25f6d'},
#  {'question': 'How do I set up Chrome Remote Desktop on a Debian Linux VM instance on Compute Engine?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1e59afc'},
#  {'question': 'What service allows remote access to applications with a GUI on Compute Engine?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1e59afc'},
#  {'question': 'What error do you get when trying to download 2021 Yellow Taxi Trip Records from the TLC website?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1e59afc'},
#  {'question': 'What is the backup link for downloading 2021 Yellow Taxi Trip Records?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1e59afc'},
#  {'question': "How do I unzip the 'gz' file for Yellow Taxi Trip Records after downloading it from the backup link?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1e59afc'},
#  {'question': 'How should the taxi data files be handled since they are *.csv.gz files?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '71c10610'},
#  {'question': 'What file name should be used to store the taxi data file?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '71c10610'},
#  {'question': "Why won't the taxi data file store correctly if the extension is csv.gz?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '71c10610'},
#  {'question': 'Is there an alternative to storing the taxi data as output.csv?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '71c10610'},
#  {'question': 'How can I modify the csv_name to read a gzipped taxi data file correctly using pandas?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '71c10610'},
#  {'question': 'Where can I find the data dictionary for Yellow Taxi trip records in NY?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '17a5aea1'},
#  {'question': 'Is there a link to the data dictionary for Green Taxi trip records?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '17a5aea1'},
#  {'question': 'What URL should I visit for the Yellow Taxi data dictionary?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '17a5aea1'},
#  {'question': 'Where is the data dictionary for Green Taxi trips?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '17a5aea1'},
#  {'question': 'Can you provide the link to the data dictionary for Yellow Taxi trips?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '17a5aea1'},
#  {'question': 'How do I unzip a downloaded parquet file in Module 1?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a275db7'},
#  {'question': 'What command should I use to unzip the green_tripdata_2019-09.csv.gz file?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a275db7'},
#  {'question': 'How can I import an unzipped CSV file using pandas in our course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a275db7'},
#  {'question': 'How do I handle parquet files directly in ingest_data.py?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a275db7'},
#  {'question': 'What changes are needed in ingest_data.py to convert a downloaded parquet file to a CSV?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a275db7'},
#  {'question': "How do I resolve 'wget is not recognized as an internal or external command' on Ubuntu?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '7ec0f9b0'},
#  {'question': 'What is the simplest way to install wget on MacOS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7ec0f9b0'},
#  {'question': 'How can I install wget on Windows using a package manager?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7ec0f9b0'},
#  {'question': 'Where can I download a wget binary for Windows, and how do I set it up?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7ec0f9b0'},
#  {'question': 'Is there an alternative to using wget for downloading files in Python, and how do I install it?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7ec0f9b0'},
#  {'question': 'What should I do if I get a certificate error with wget on MacOS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'bb1ba786'},
#  {'question': ' How can I use wget in a Jupyter Notebook?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'bb1ba786'},
#  {'question': 'Is there a way to bypass certificate verification when using wget?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'bb1ba786'},
#  {'question': 'When running wget from the CLI on MacOS, how do I handle certificate errors?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'bb1ba786'},
#  {'question': 'Can I use a Python library to handle wget certificate errors?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'bb1ba786'},
#  {'question': 'How can I use the backslash as an escape character in Git Bash for Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f83dbe7'},
#  {'question': 'What command should I type in the terminal to use backslash as an escape character?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f83dbe7'},
#  {'question': 'Is it necessary to include the bash.escapeChar=\\ command in the .bashrc file?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f83dbe7'},
#  {'question': "What is the purpose of typing 'bash.escapeChar=\\' in Git Bash?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f83dbe7'},
#  {'question': 'Who normally uses the backslash as an escape character in Git Bash for Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f83dbe7'},
#  {'question': 'How can I store secrets in GitHub Codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '543ff080'},
#  {'question': 'Where can I find instructions for storing secrets in Codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '543ff080'},
#  {'question': 'What document should I refer to for managing account-specific secrets in GitHub Codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '543ff080'},
#  {'question': 'Is there a guide for storing secrets to be available in Codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '543ff080'},
#  {'question': 'How do I manage secrets for GitHub Codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '543ff080'},
#  {'question': 'How can I resolve a connection issue with the Docker daemon at unix:///var/run/docker.sock?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd407d65b'},
#  {'question': 'What should I do if I cannot start the Docker daemon?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd407d65b'},
#  {'question': 'How do I check if the Docker daemon is running correctly?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd407d65b'},
#  {'question': 'What command can I use in PowerShell to update wsl for Docker?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd407d65b'},
#  {'question': 'Is there a specific command to update wsl in PowerShell for Docker issues?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd407d65b'},
#  {'question': 'What should Windows 10 Pro/11 Pro users do to enable Docker using Hyper-V?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c9375c56'},
#  {'question': 'What back-end option do Windows 10 Home/ 11 Home users have for running Docker?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c9375c56'},
#  {'question': 'What resource should be referred to for detailed WSL2 installation instructions for Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c9375c56'},
#  {'question': 'Where can I find guidelines to update the WSL2 Linux Kernel if I encounter the error 0x800701bc?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c9375c56'},
#  {'question': 'Is Hyper-V available as a back-end option for Docker on Windows 10 Home/ 11 Home versions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c9375c56'},
#  {'question': 'Why do I need to use Docker Desktop instead of Rancher Desktop when encountering a permission denied error on macOS M1?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e866156b'},
#  {'question': "What should I do if I mistakenly get a 'docker login: denied' message when pulling a Docker image?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e866156b'},
#  {'question': "When am I required to execute a 'docker login' command before performing a 'docker pull'?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e866156b'},
#  {'question': "What could be the reason for receiving an 'Error response from daemon' when creating a PostgreSQL Docker container with a mounted volume?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e866156b'},
#  {'question': 'Are all Docker Images used in the Data Engineering Zoomcamp public, or do I need to login for some?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e866156b'},
#  {'question': 'How do I delete a local folder mounted to a Docker volume?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '16370470'},
#  {'question': 'What command should I use to remove a folder created by PostgreSQL in Docker?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '16370470'},
#  {'question': "Why can't I delete a Docker-mounted folder by dragging it to the trash?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '16370470'},
#  {'question': 'How can I resolve access errors caused by a Docker-mounted folder?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '16370470'},
#  {'question': "What does the '-f' flag in the 'sudo rm -r -f' command do?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '16370470'},
#  {'question': "How can I fix Docker if it's stuck on starting in Windows 10 or 11?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '316df755'},
#  {'question': "What should I do if the Docker 'Upgrade' menu isn't working?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '316df755'},
#  {'question': 'What steps can I follow to switch containers from Windows to Linux for Docker?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '316df755'},
#  {'question': 'How do I enable Hyper-V on Windows 10 or 11 to run Docker?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '316df755'},
#  {'question': 'Is there a tutorial to follow if I choose WSL2 as the backend for Docker on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '316df755'},
#  {'question': 'Should I run Docker commands from the Windows file system or a Linux file system in WSL?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f3aa9252'},
#  {'question': 'Can I use Docker with Windows 10/11 Home Edition?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f3aa9252'},
#  {'question': 'What should I do if Docker remains stuck even after setting up WSL2?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f3aa9252'},
#  {'question': 'Is there a tutorial for making Docker work with WSL2 on Windows Home Edition?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f3aa9252'},
#  {'question': 'How can I reset Docker if it’s not working properly after setup?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f3aa9252'},
#  {'question': 'Why should I store all code in my default Linux distro when using Docker on Windows 10 Home?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a4abe7a5'},
#  {'question': 'How can I improve file system performance for Docker on Windows 11 Home?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a4abe7a5'},
#  {'question': 'Why does Docker run on the WSL2 backend by default?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a4abe7a5'},
#  {'question': 'Where can I find more information on Docker best practices?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a4abe7a5'},
#  {'question': 'What is the recommended setup for Docker on Windows 10 Home for optimal performance?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a4abe7a5'},
#  {'question': "What should I do if I get 'the input device is not a TTY' error when running Docker on Windows?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fb930700'},
#  {'question': 'How can I resolve the TTY error using winpty for Docker commands?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fb930700'},
#  {'question': 'What is the workaround for the TTY error on Docker when using mintty?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fb930700'},
#  {'question': 'How can I create a persistent solution to avoid the TTY error in Docker on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fb930700'},
#  {'question': 'Where should I add the alias to use winpty automatically with Docker commands?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fb930700'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'aa187680'},
#  {'question': 'Why is the ny_taxi_postgres_data folder empty even after running the docker script in VS Code?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b000e899'},
#  {'question': 'What should I do if the ny_taxi_postgres_data folder is empty in VS Code on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b000e899'},
#  {'question': 'How can I fix the issue of the empty ny_taxi_postgres_data folder in Docker for Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b000e899'},
#  {'question': 'Which Docker command should I use to ensure the ny_taxi_postgres_data folder is populated correctly in VS Code?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b000e899'},
#  {'question': 'What is the correct way to quote the absolute path in the -v parameter on Windows to solve the ny_taxi_postgres_data folder issue?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b000e899'},
#  {'question': 'Where can I find details about setting up Docker on a Mac?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9c66759f'},
#  {'question': 'Has the method for setting up Docker on macOS become outdated?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9c66759f'},
#  {'question': 'Is there an alternative way to set up Docker on macOS besides using the article?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9c66759f'},
#  {'question': 'What licensing change has affected the method of setting up Docker on macOS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9c66759f'},
#  {'question': 'What is the recommended way to install Docker on macOS without facing issues?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9c66759f'},
#  {'question': "How can one fix the 'Operation not permitted' error when changing permissions of '/var/lib/postgresql/data' in Docker?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e3106e07'},
#  {'question': 'How do I create a local docker volume and map it to the postgres data directory?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e3106e07'},
#  {'question': 'Which Docker command verifies the volume creation under WSL2 Ubuntu 22.04?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e3106e07'},
#  {'question': "What should I do if the directory '/var/lib/postgresql/data' is not empty when initializing the database?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e3106e07'},
#  {'question': "Where can I find the 'dtc_postgres_volume_local' volume in the Docker Desktop app?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e3106e07'},
#  {'question': "What can I do if I encounter the Docker error 'invalid reference format: repository name must be lowercase'?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '72229da5'},
#  {'question': "What are the different ways to replace the '-v' part of the Docker command on Windows when mapping volumes?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '72229da5'},
#  {'question': 'How should I modify the Docker command on Windows if the mapped folder contains spaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72229da5'},
#  {'question': 'What solution can I use if none of the provided Docker options for volume mapping work?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72229da5'},
#  {'question': 'How do I configure the Docker command for mapping volumes on a Mac?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72229da5'},
#  {'question': "How can I fix the 'invalid mode' error in Docker when using the mounting path?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '58c9f99f'},
# ...
#   'course': 'data-engineering-zoomcamp',
#   'document': 'da899638'},
#  {'question': 'What are the steps involved in the ETL process from web to GCS as described in Module 2?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'da899638'},
#  {'question': 'Why does my WSL2 crash or hang when running the ETL script from web to GCS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'da899638'},
#  {'question': 'How can I increase the timeout value for uploading files to GCS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'da899638'},
#  {'question': 'What should I do if I get the UndefinedColumn error while exporting transformed green_taxi data to PostgreSQL?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'dde58c8f'},
#  {'question': "How can I resolve the issue when the 'ratecode_id' column does not exist in the green_taxi table during re-export?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'dde58c8f'},
#  {'question': "What steps should I take if the green_taxi table lacks columns like 'vendor_id' when running the export block?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'dde58c8f'},
#  {'question': 'How do I handle the error when trying to re-run the export block for green_taxi data with missing columns in PostgreSQL?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'dde58c8f'},
#  {'question': "What needs to be done if I encounter a missing column error for 'pu_location_id' in the green_taxi relation during data export?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'dde58c8f'},
#  {'question': 'How can I avoid SettingWithCopyWarning in Module 2 homework?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '207be93b'},
#  {'question': 'What does SettingWithCopyWarning indicate in Workflow Orchestration?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '207be93b'},
#  {'question': 'Which syntax should I use to prevent SettingWithCopyWarning in my dataframe operations?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '207be93b'},
#  {'question': 'Why does SettingWithCopyWarning occur when working with dataframes?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '207be93b'},
#  {'question': 'How do I ensure a new column is assigned to the original dataframe instead of a copy?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '207be93b'},
#  {'question': 'How can I handle big CSV files if my laptop is slow?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f0617e65'},
#  {'question': 'What should I use instead of Pandas for large NYC data on a slow laptop?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f0617e65'},
#  {'question': 'Where can I find the documentation for using the Pyspark kernel in Mage?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f0617e65'},
#  {'question': 'Can I use Pyspark kernel in Mage for big CSV files?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f0617e65'},
#  {'question': 'Which kernel is recommended for large datasets in Module 2?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f0617e65'},
#  {'question': 'How do I delete a block from a pipeline in Module 2?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6290a1a6'},
#  {'question': 'What should I do if I get an error deleting a block in Workflow Orchestration?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6290a1a6'},
#  {'question': 'Is there a specific order to removing blocks in Module 2?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6290a1a6'},
#  {'question': 'What is the initial step to fixing deletion errors in a pipeline?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6290a1a6'},
#  {'question': 'Do I need to disconnect any connections before deleting a block in a pipeline?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6290a1a6'},
#  {'question': "What should I do if I can't edit the Pipeline name in Mage UI?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a06248c'},
#  {'question': 'Why do I get a permission denied error when trying to change the Pipeline name?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a06248c'},
#  {'question': 'What is the workaround for editing the Pipeline name in Mage UI?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a06248c'},
#  {'question': 'Can I save my work and still edit the Pipeline name later in Mage UI?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a06248c'},
#  {'question': 'Will revisiting the Mage UI allow me to change the Pipeline name?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a06248c'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c46a2e9e'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0513ab8a'},
#  {'question': 'How do I add Mage files and homework to my Data Engineering Zoomcamp repo?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a9385356'},
#  {'question': "Why can't I include Mage repo files directly in my DE Zoomcamp repo?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a9385356'},
#  {'question': 'What steps are needed to de-couple the Mage repo from its original source?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a9385356'},
#  {'question': 'What should I do with the .gitignore file when adding Mage files to my main repo?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a9385356'},
#  {'question': 'How do I handle Git tracking issues when moving Mage files to my DE Zoomcamp repo?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a9385356'},
#  {'question': 'What causes the ValueError: The truth value of a Series is ambiguous in the current assertions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c30468c0'},
#  {'question': 'How should assertions for passenger_count and trip_distance be correctly combined to avoid ValueError?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c30468c0'},
#  {'question': 'What assertion should be added to check if vendor_id exists in the column?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c30468c0'},
#  {'question': 'What did a Stackoverflow discussion suggest for correcting the ambiguous Series truth value error?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c30468c0'},
#  {'question': 'How can data_filter be written to avoid the ValueError when ensuring passenger_count > 0 and trip_distance > 0?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c30468c0'},
#  {'question': 'Why do my Mage AI files disappear after rebooting my PC?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '305aead7'},
#  {'question': 'What should I do if my Mage AI files are gone after restarting?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '305aead7'},
#  {'question': 'How can I properly shut down Mage Docker Compose?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '305aead7'},
#  {'question': "Which command should I use to check if I'm in the correct repository before running Docker Compose?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '305aead7'},
#  {'question': 'Where was the issue of disappearing Mage AI files discussed?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '305aead7'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': '77410975'},
#  {'question': 'What should I do if Mage throws an ArrowException about not opening credentials file while exporting data to GCS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0952abde'},
#  {'question': 'How can I fix the Google authentication error in Mage when exporting to a GCS bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0952abde'},
#  {'question': 'Where should I place the GCP credentials .json file to resolve the Mage export error?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0952abde'},
#  {'question': 'What steps are necessary to create and configure a credentials file in Mage?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0952abde'},
#  {'question': 'What specific environment variable needs to be updated in Mage to point to the GCP credentials file?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0952abde'},
#  {'question': 'What can cause an OSError in Mage?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c4326eb'},
#  {'question': 'How can I fix exhausted retry policy errors in Google Cloud?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c4326eb'},
#  {'question': 'Why was my request not sent due to OAuth2 issues?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c4326eb'},
#  {'question': 'Where can I learn more about Google Cloud authentication?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c4326eb'},
#  {'question': 'What does curl error [6] imply in Google Cloud operations?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c4326eb'},
#  {'question': "What should I do if I get a PermissionError saying the service account doesn't have storage.buckets.get access in Mage?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1fc1a14'},
#  {'question': "Why am I seeing a 'Permission denied' error when exporting data from Mage to a Google Cloud Storage bucket?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1fc1a14'},
#  {'question': 'Can you explain the steps to grant the necessary permissions to my service account in Google Cloud?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1fc1a14'},
#  {'question': "How do I fix the 'PERMISSION_DENIED' issue while accessing my Google Cloud Storage bucket from Mage?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1fc1a14'},
#  {'question': 'What is the required role for a service account to access a Google Cloud Storage bucket in Mage?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1fc1a14'},
#  {'question': 'What preparation is necessary for a pyspark script before sending it to Dataproc cluster?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6d67fba9'},
#  {'question': 'How do I create a Dataproc Cluster in GCP Console?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6d67fba9'},
#  {'question': 'What role should be added to the service account for Dataproc?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6d67fba9'},
#  {'question': 'Where should I place the python script for Dataproc?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6d67fba9'},
#  {'question': 'Is gcloud CLI required for Mage to access Dataproc and how can I install it?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6d67fba9'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': '06876291'},
#  {'question': 'What should I do if I encounter an error writing data to a GCS bucket from the web?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '690ba010'},
#  {'question': 'How can I resolve issues when writing data from a web app to GCS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '690ba010'},
#  {'question': 'What data types should I use to prevent GCS bucket write errors?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '690ba010'},
#  {'question': 'Are there recommended data types for writing web data to GCS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '690ba010'},
#  {'question': 'How do Nullable dataTypes help in writing data to a GCS bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '690ba010'},
#  {'question': 'What should I ensure about the schema of files in a directory before ingesting them into a BigQuery table?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b6fdd91d'},
#  {'question': 'Why do I get a parquet column type mismatch error when importing files to BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b6fdd91d'},
#  {'question': 'How are the schemas of FHV datasets from different months in 2019 inconsistent?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b6fdd91d'},
#  {'question': 'What defines the schema when importing multiple parquet files to BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b6fdd91d'},
#  {'question': 'How can I prevent schema mismatch errors when importing data to BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b6fdd91d'},
#  {'question': "What should I do if I encounter the error gzip.BadGzipFile: Not a gzipped file (b'\\n\\n') when importing FHV data to GCS?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '155aa868'},
#  {'question': "Why might I receive an error saying 'gzip.BadGzipFile: Not a gzipped file' when importing FHV data to GCS?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '155aa868'},
#  {'question': 'What is the correct URL to use for importing FHV data to GCS to avoid the gzip.BadGzipFile error?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '155aa868'},
#  {'question': 'How can I ensure I am using the right URL for the FHV dataset to avoid import errors in GCS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '155aa868'},
#  {'question': 'What part of the URL is critical to include when importing the FHV dataset to GCS to avoid the gzip.BadGzipFile error?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '155aa868'},
#  {'question': 'Who is the expert for loading data from a URL list into a GCP bucket in Module 3?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e78cf960'},
#  {'question': 'Who can help with loading data into a GCP bucket from URLs in Module 3?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e78cf960'},
#  {'question': 'In Module 3, who assists with loading data from a URL list into a GCP bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e78cf960'},
#  {'question': 'For Module 3, who guides on loading data from a URL list into a GCP bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e78cf960'},
#  {'question': 'Who to refer to in Module 3 for loading data from a URL list into a GCP bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e78cf960'},
#  {'question': 'What should I do when I get a Bad character (ASCII 0) error while querying my dataset?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9afa1f74'},
#  {'question': 'How can I fix a wrong formatting issue in my dataset?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9afa1f74'},
#  {'question': 'Why do I get an error when uploading CSV.GZ files through pandas?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9afa1f74'},
#  {'question': 'How can I avoid formatting issues when uploading my dataset to a GCS Bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9afa1f74'},
#  {'question': 'Where can I find tips for solving the Bad character (ASCII 0) error in my dataset?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9afa1f74'},
#  {'question': 'How do I check if the BigQuery Command Line Tool is installed?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fac138a7'},
#  {'question': "What should I do if I get 'bq: command not found'?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fac138a7'},
#  {'question': "Is there an alternative command for 'bq'?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fac138a7'},
#  {'question': 'Where can I find the BigQuery Command Line Tool in GCP?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fac138a7'},
#  {'question': 'What command lists installed GCP components?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fac138a7'},
#  {'question': 'What should I do to avoid a large bill when using BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0174dde5'},
#  {'question': 'Is it important to check my billing daily when using Google Cloud Platform?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0174dde5'},
#  ...]

# %%
relevance_total = []

for q in tqdm(ground_truth):
    doc_id = q['document']
    results = elastic_search(query=q['question'], course=q['course'])
    relevance = [d['id'] == doc_id for d in results]
    relevance_total.append(relevance)
# Out:
#   0%|          | 0/4631 [00:00<?, ?it/s]

# %%
relevance,  results
# Out:
# ([False, False, True, False, False],
#  [{'text': "Yes, even if you don't register, you're still eligible to submit the homeworks.\nBe aware, however, that there will be deadlines for turning in the final projects. So don't leave everything for the last minute.",
#    'section': 'General course-related questions',
#    'question': 'Course - Can I still join the course after the start date?',
#    'course': 'data-engineering-zoomcamp',
#    'id': '7842b56a'},
#   {'text': 'After you submit your homework it will be graded based on the amount of questions in a particular homework. You can see how many points you have right on the page of the homework up top. Additionally in the leaderboard you will find the sum of all points you’ve earned - points for Homeworks, FAQs and Learning in Public. If homework is clear, others work as follows: if you submit something to FAQ, you get one point, for each learning in a public link you get one point.\n(https://datatalks-club.slack.com/archives/C01FABYF2RG/p1706846846359379?thread_ts=1706825019.546229&cid=C01FABYF2RG)',
#    'section': 'General course-related questions',
#    'question': 'Homework and Leaderboard - what is the system for points in the course management platform?',
#    'course': 'data-engineering-zoomcamp',
#    'id': '29865466'},
#   {'text': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#    'section': 'General course-related questions',
#    'question': 'Course - When will the course start?',
#    'course': 'data-engineering-zoomcamp',
#    'id': 'c02e79ef'},
#   {'text': 'GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites',
#    'section': 'General course-related questions',
#    'question': 'Course - What are the prerequisites for this course?',
#    'course': 'data-engineering-zoomcamp',
#    'id': '1f6520ca'},
#   {'text': 'You can start by installing and setting up all the dependencies and requirements:\nGoogle cloud account\nGoogle Cloud SDK\nPython 3 (installed with Anaconda)\nTerraform\nGit\nLook over the prerequisites and syllabus to see if you are comfortable with these subjects.',
#    'section': 'General course-related questions',
#    'question': 'Course - What can I do before the course starts?',
#    'course': 'data-engineering-zoomcamp',
#    'id': '63394d91'}])

# %%
example = [
    [True, False, False, False, False], # 1, 
    [False, False, False, False, False], # 0
    [False, False, False, False, False], # 0 
    [False, False, False, False, False], # 0
    [False, False, False, False, False], # 0 
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1 
    [False, False, True, False, False],  # 1/3
    [False, False, False, False, False], # 0
]

# 1 => 1
# 2 => 1 / 2 = 0.5
# 3 => 1 / 3 = 0.3333
# 4 => 0.25
# 5 => 0.2
# rank => 1 / rank
# none => 0

# %%
def hit_rate(relevance_total):
    cnt = 0

    for line in relevance_total:
        if True in line:
            cnt = cnt + 1

    return cnt / len(relevance_total)

# %%
def mrr(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank] == True:
                total_score = total_score + 1 / (rank + 1)

    return total_score / len(relevance_total)

# %%
hit_rate(example)
# Out:
# 0.5833333333333334

# %%
mrr(example)
# Out:
# 0.5277777777777778

# %%
hit_rate(relevance_total), mrr(relevance_total)
# Out:
# (0.7447635499892032, 0.6087742028359607)

# %%
import minsearch

index = minsearch.Index(
    text_fields=["question", "text", "section"],
    keyword_fields=["course", "id"]
)

index.fit(documents)

# %%
def minsearch_search(query, course):
    boost = {'question': 3.0, 'section': 0.5}

    results = index.search(
        query=query,
        filter_dict={'course': course},
        boost_dict=boost,
        num_results=5
    )

    return results

# %%
relevance_total = []

for q in tqdm(ground_truth):
    doc_id = q['document']
    results = minsearch_search(query=q['question'], course=q['course'])
    relevance = [d['id'] == doc_id for d in results]
    relevance_total.append(relevance)
# Out:
#   0%|          | 0/4631 [00:00<?, ?it/s]

# %%
hit_rate(relevance_total), mrr(relevance_total)
# Out:
# (0.7799611315050745, 0.6694126538544594)

# %% [markdown]
# Compare with ES results:
#
# (0.7395720769397017, 0.6032418413658963)

# %%
def evaluate(ground_truth, search_function):
    relevance_total = []

    for q in tqdm(ground_truth):
        doc_id = q['document']
        results = search_function(q)
        relevance = [d['id'] == doc_id for d in results]
        relevance_total.append(relevance)

    return {
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %%
evaluate(ground_truth, lambda q: elastic_search(q['question'], q['course']))
# Out:
#   0%|          | 0/4631 [00:00<?, ?it/s]
# {'hit_rate': 0.7447635499892032, 'mrr': 0.6087742028359607}

# %%
evaluate(ground_truth, lambda q: minsearch_search(q['question'], q['course']))
# Out:
#   0%|          | 0/4631 [00:00<?, ?it/s]
# {'hit_rate': 0.7799611315050745, 'mrr': 0.6694126538544594}
